# %% [markdown]
# <a href="https://colab.research.google.com/github/gyanamc/sbicard-slm/blob/main/train_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train SBI Card SLM on Google Colab
#
# This notebook sets up the environment and runs the training script for the SBI Card SLM project.
#
# **Before running:** Set **Runtime → Change runtime type → GPU** (T4 or better).
# See `TRAINING_GUIDE_GOOGLE_COLAB.md` in the repo for full step-by-step instructions and data format details.

# %%
# Clone the repository
# !git clone https://github.com/gyanamc/sbicard-slm.git
# %cd sbicard-slm

# %%
# Install dependencies
# !pip install -q -r requirements.txt

# Verify GPU (required for QLoRA)
import torch
assert torch.cuda.is_available(), "Enable GPU: Runtime → Change runtime type → GPU"
print(f"GPU: {torch.cuda.get_device_name(0)}")

# %%
# Run training (config: config.yaml; dataset: sbicard_instructions.jsonl or test_augmented.jsonl fallback)
# !python training/train_model.py

# %%
# Save trained model (Colab disk is temporary — download this zip or push to Hugging Face Hub)
# !zip -r sbicard-slm-1.4b.zip sbicard-slm-1.4b
print("Download sbicard-slm-1.4b.zip from the Files panel (left sidebar).")
